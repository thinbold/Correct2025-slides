# %% [markdown]
# ## RREF

# %%
F.<a> = GF(4, repr='log')

# %%
A = matrix(F, [
    [1, 2, 1, 2, 1, 2],
    [2, 3, 3, 2, 2, 3],
    [2, 1, 1, 3, 3, 3]
])

# %%
A.rref()
# Out:
# [3 0 3 0 3 0]
# [0 3 3 0 0 3]
# [0 0 0 3 3 0]

# %%
vector(GF(7), [3, 2]) * matrix(GF(7), [
    [1, 1, 1, 1, 1, 1, 1],
    [0, 1, 2, 3, 4, 5, 6]
])
# Out:
# (3, 5, 0, 2, 4, 6, 1)

# %%
vector(GF(7), [2, 6, 1]) * matrix(GF(7), [
    [1, 1, 1, 1, 1, 1, 1],
    [0, 1, 2, 3, 4, 5, 6],
    [0, 1, 4, 2, 2, 4, 1]
])
# Out:
# (2, 2, 4, 1, 0, 1, 4)

# %% [markdown]
# ## BP

# %%
f(x) = x * (1 - (1 - x)^5)^2

# %%
f(1/2).n()
# Out:
# 0.469238281250000

# %%
f(f(1/2)).n()
# Out:
# 0.430541284779776

# %%
f(f(f(1/2))).n()
# Out:
# 0.380520130802175

# %%
f(f(f(f(1/2)))).n()
# Out:
# 0.314257708438611
