# %%
10^2
# Out:
# 100

# %%
f(x) = x * (1 - (1 - x)^5)^2

# %%
f(1/3).n()
# Out:
# 0.251322348106375

# %%
f(f(1/3)).n()
# Out:
# 0.146995516934721

# %%
f(f(f(1/3))).n()
# Out:
# 0.0442073663087139

# %%
F.<a> = GF(64, repr='log')

# %%
a^12 + a^34
# Out:
# 58
